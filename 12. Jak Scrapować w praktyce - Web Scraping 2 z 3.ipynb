# %%
import requests
from bs4 import BeautifulSoup

url = 'https://www.morizon.pl/oferta/sprzedaz-mieszkanie-krakow-swoszowice-borkowska-28m2-mzn2044084554'
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')

# %%
values = [flat for flat in soup.find_all('div', id = 'basic-info-price-row')][0]
values

# %%
spans = values.find_all('span')
spans

# %%
def text_to_float(txt):
    return float(''.join(c for c in txt if c in [str(i) for i in range(10)]))

# %%
price = text_to_float(spans[0].text)
price

# %%
priece_per_metr = text_to_float(spans[1].text)
priece_per_metr

# %% [markdown]
# Więcej szczegółów

# %%
next_data = values.next_sibling()
next_data

# %%
pokoje = next_data[0].span.text
pokoje

# %%
pietro = next_data[6].span.text
pietro

# %%
locations = values = [flat for flat in soup.find_all('h2')][1]
locations

# %%
location = [n.text.strip().strip(',') for n in locations.find_all('span')]
location

# %%
location = ", ".join(location)
location

# %%
[flat for flat in soup.find_all('h1')][0].text

# %%
def text_to_float(txt):
    return float(''.join(c for c in txt if c in [str(i) for i in range(10)]))

def flat_to_dict(soup):
    node = [flat for flat in soup.find_all('div', id = 'basic-info-price-row')][0]
    spans = node.find_all('span')
    next_data = node.next_sibling()
    locations = values = [flat for flat in soup.find_all('h2')][1]
    location = [n.text.strip().strip(',') for n in locations.find_all('span')]
    return{
        'price': text_to_float(spans[0].text),
        'price_per_metr': text_to_float(spans[1].text),
        'rooms': next_data[0].span.text,
        'floor': next_data[6].span.text,
        'location': ", ".join(location),
        'title': [flat for flat in soup.find_all('h1')][0].text
    }

# %%
flat_to_dict(soup)

# %%
import scrapy
import scrapy.crawler as crawler
from bs4 import BeautifulStoneSoup

from scrapy.crawler import CrawlerProcess

class MySpider(scrapy.Spider):
    name = 'my_morizon_spider'
    start_urls = [
        'https://www.morizon.pl/mieszkania/krakow/'
    ]
    
    item_urls2 = ['https://www.morizon.pl/mieszkania/krakow/?page=2']

    custom_settings = {
        'DOWNLOAD_DELAY': '2.0',
        'ROBOTSTXT_OBEY': True,
        'AUTOTHROTTLE_ENABLE': True,
        'USER_AGENT': 'My Morizon Demo Bot (qwerty@nirpodam.pl)'
        }
    top_url = 'https://www.morizon.pl/'

    def parse(self, response):
        self.logger.info('1. Got successful response from{}'.format(response.url))

        for item_url in self.item_url2:
            yield scrapy.Request(item_url, self.parse)

# %%
process = CrawlerProcess()
process.crawl(MySpider)
process.start()

# %%
import scrapy
import scrapy.crawler as crawler
from bs4 import BeautifulSoup

from scrapy.crawler import CrawlerProcess

class MySpider(scrapy.Spider):
    name = 'my_morizon_spider'
    start_urls = [
        'https://www.morizon.pl/mieszkania/krakow/'
    ]

    custom_settings = {
        'DOWNLOAD_DELAY': '4.0',
        'ROBOTSTXT_OBEY': True,
        'AUTOTHROTTLE_ENABLE': True,
        'USER_AGENT': 'My Morizon Demo Bot (qwerty@nirpodam.pl)'
        }

    def parse(self, response):
        self.logger.info('Got successful response from{}'.format(response.url))
        soup = BeautifulSoup(response.body, 'lxml')

        links = [link.get('href') for link in soup.find_all('a')]

        links = links[:100]
        print(links)

        for item_url in links:
            yield scrapy.Request(item_url, self.parse_item)

    def parse_item(self, response):
        self.logger.info('Got successful response from {}'.format(response.url))

# %%
process = CrawlerProcess()
process.crawl(MySpider)
process.start()
# Out:
# 2024-07-10 13:46:57 [scrapy.utils.log] INFO: Scrapy 2.11.2 started (bot: scrapybot)
# 2024-07-10 13:46:57 [scrapy.utils.log] INFO: Versions: lxml 5.2.2.0, libxml2 2.12.7, cssselect 1.2.0, parsel 1.9.1, w3lib 2.1.2, Twisted 24.3.0, Python 3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 24.0.0 (OpenSSL 3.3.1 4 Jun 2024), cryptography 42.0.7, Platform Windows-10-10.0.17134-SP0
# 2024-07-10 13:46:57 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-07-10 13:46:57 [py.warnings] WARNING: D:\anaconda3\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2024-07-10 13:46:58 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2024-07-10 13:46:58 [scrapy.extensions.telnet] INFO: Telnet Password: 6ab496b8d7e5a9ae
# 2024-07-10 13:46:59 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2024-07-10 13:46:59 [scrapy.crawler] INFO: Overridden settings:
# {'DOWNLOAD_DELAY': '4.0',
#  'ROBOTSTXT_OBEY': True,
#  'USER_AGENT': 'My Morizon Demo Bot (qwerty@nirpodam.pl)'}
# 2024-07-10 13:47:01 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-07-10 13:47:01 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-07-10 13:47:01 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-07-10 13:47:01 [scrapy.core.engine] INFO: Spider opened
# 2024-07-10 13:47:01 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-07-10 13:47:01 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2024-07-10 13:47:01 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.morizon.pl/robots.txt> (referer: None)
# 2024-07-10 13:47:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.morizon.pl/mieszkania/krakow/> (referer: None)
# 2024-07-10 13:47:05 [my_morizon_spider] INFO: Got successful response fromhttps://www.morizon.pl/mieszkania/krakow/
# 2024-07-10 13:47:05 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.morizon.pl/mieszkania/krakow/> (referer: None)
# Traceback (most recent call last):
#   File "D:\anaconda3\Lib\site-packages\scrapy\utils\defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "D:\anaconda3\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "D:\anaconda3\Lib\site-packages\scrapy\utils\python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "D:\anaconda3\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "D:\anaconda3\Lib\site-packages\scrapy\spidermiddlewares\referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\anaconda3\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "D:\anaconda3\Lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\anaconda3\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "D:\anaconda3\Lib\site-packages\scrapy\spidermiddlewares\depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\anaconda3\Lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     for r in iterable:
#   File "C:\Users\Toma\AppData\Local\Temp\ipykernel_8900\3006667476.py", line 30, in parse
#     yield scrapy.Request(item_url, self.parse_item)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\anaconda3\Lib\site-packages\scrapy\http\request\__init__.py", line 93, in __init__
#     self._set_url(url)
#   File "D:\anaconda3\Lib\site-packages\scrapy\http\request\__init__.py", line 143, in _set_url
#     raise ValueError(f"Missing scheme in request url: {self._url}")
# ValueError: Missing scheme in request url: /
# 2024-07-10 13:47:05 [scrapy.core.engine] INFO: Closing spider (finished)
# 2024-07-10 13:47:05 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 488,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 100574,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 2,
#  'elapsed_time_seconds': 4.372803,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2024, 7, 10, 11, 47, 5, 888406, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 603887,
#  'httpcompression/response_count': 2,
#  'log_count/DEBUG': 3,
#  'log_count/ERROR': 1,
#  'log_count/INFO': 11,
#  'log_count/WARNING': 1,
#  'response_received_count': 2,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'spider_exceptions/ValueError': 1,
#  'start_time': datetime.datetime(2024, 7, 10, 11, 47, 1, 515603, tzinfo=datetime.timezone.utc)}
# 2024-07-10 13:47:05 [scrapy.core.engine] INFO: Spider closed (finished)
'/oferta/sprzedaz-mieszkanie-krakow-podgorze-rydlowka-39m2-mzn2042092351', '/oferta/sprzedaz-mieszkanie-krakow-podgorze-duchacki ...

# %%
import IPython

IPython.Application.instance().kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}

# %%
import scrapy
import scrapy.crawler as crawler
from bs4 import BeautifulSoup
from scrapy.crawler import CrawlerProcess
import logging

def text_to_float(txt):
    return float(''.join(c for c in txt if c in [str(i) for i in range(10)]))

def flat_to_dict(soup):
    node = [flat for flat in soup.find_all('div', id = 'basic-info-price-row')][0]
    spans = node.find_all('span')
    no_spans = (len(spans)<2)
    next_data = node.next_sibling()
    locations = values = [flat for flat in soup.find_all('h2')][1]
    location = [n.text.strip().strip(',') for n in locations.find_all('span')]
    return{
        'price': '' if no_spans else text_to_float(spans[0].text),
        'price_per_metr': '' if no_spans else text_to_float(spans[1].text),
        'rooms': next_data[0].span.text,
        'floor': next_data[6].span.text,
        'location': ", ".join(location),
        'title': [flat for flat in soup.find_all('h1')][0].text
    }

results = []

class MySpider(scrapy.Spider):
    name = 'my_morizon_spider'
    start_urls = [
        'https://www.morizon.pl/mieszkania/krakow/?page=%d' %i for i in range(1,3)
    ]

    custom_settings = {
        'DOWNLOAD_DELAY': '4.0',
        'ROBOTSTXT_OBEY': True,
        'AUTOTHROTTLE_ENABLE': True,
        'USER_AGENT': 'My Morizon Demo Bot (qwerty@niepodam.pl)'
        }

    def __init__(self, *args, **kwargs):
        logger = logging.getLogger("scrapy.spidermiddlewares.httperror")
        logger.setLevel(logging.WARNING)
        logger = logging.getLogger("scrapy.score.engine")
        logger.setLevel(logging.WARNING)
        super().__init__(*args, **kwargs)

    def parse(self, response):
        self.logger.setLevel(logging.INFO)
        soup = BeautifulSoup(response.body, 'lxml')

        links = [link.get('href') for link in soup.find_all('a')]

        links = [ 'https://www.morizon.pl'+link for link in links if link.startswith('/oferta')]
        
        for item_url in links:
            yield scrapy.Request(item_url, self.parse_item)

    def parse_item(self, response):
        self.logger.info('Got successful response from {}'.format(response.url))
        soup = BeautifulSoup(response.body, 'lxml')
        data = flat_to_dict(soup)
        data['url'] = response.url
        results.append(data)


    def spider_closed(self, spider):
        try:
            from datetime import datetime
            
            spider.logger.info('Spider closed: %s', spider.name)
            now = datetime.now().strftime("%Y-%m-%d")
            spider.logger.info('Spider closed: %s', spider.name)
            df = pd.DataFrame(results)
            fname = f"data/morizon-{now}.csv"
            print(fname)
            spider.logger.info('Spider writing to: %s', fname)
            df.to_csv(fname)
        except Exception as e:
            print(e)

# %%
import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)

process = CrawlerProcess()
process.crawl(MySpider)
process.start()
# Out:
# 2024-07-10 15:27:02 [scrapy.utils.log] INFO: Scrapy 2.11.2 started (bot: scrapybot)
# 2024-07-10 15:27:02 [scrapy.utils.log] INFO: Versions: lxml 5.2.2.0, libxml2 2.12.7, cssselect 1.2.0, parsel 1.9.1, w3lib 2.1.2, Twisted 24.3.0, Python 3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 24.0.0 (OpenSSL 3.3.1 4 Jun 2024), cryptography 42.0.7, Platform Windows-10-10.0.17134-SP0
# 2024-07-10 15:27:02 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-07-10 15:27:02 [py.warnings] WARNING: D:\anaconda3\Lib\site-packages\scrapy\utils\request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2024
(referer: https://www.morizon.pl/mieszkania/krakow/?page=2)
# 2024-07-10 15:32:14 [my_morizon_spider] INFO: Got successful response from https://www.morizon.pl/oferta/sprzedaz-mieszkanie-krakow-stare-miasto-prandoty-10c-36m2-mzn2041533825
# 2024-07-10 15:32:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.morizon.pl/oferta/sprzedaz-mieszkanie-krakow-podgorze-rydlowka-49m2-mzn2042319747> (referer: https://www.morizon.pl/mieszkania/krakow/?page=2)
# 2024-07-10 15:32:20 [my_morizon_spider] INFO: Got successful response from https://www.morizon.pl/oferta/sprzedaz-mieszkanie-krakow-podgorze-rydlowka-49m2-mzn2042319747
# 2024-07-10 15:32:26 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.morizon.pl/oferta/sprzedaz-mieszkanie-krakow-podgorze-mysliwska-68-62m2-mzn2043447274> (referer: https://www.morizon.pl/mieszkania/krakow/?page=2)
# 2024-07-10 15:32:26 [my_morizon_spider] INFO: Got successful response from https://www.morizon.pl/oferta/sprzedaz-mieszkanie-krakow-podgorze-mysliwska-68-62m2-mzn2043447274
# 2024-07-10 15:32:32 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.morizon.pl/oferta/sprzedaz-mieszkanie-krakow-podgorze-mysliwska-68-64m2-mzn2043447269> (referer: https://www.morizon.pl/mieszkania/krakow/?page=2)
# 2024-07-10 15:32:32 [my_morizon_spider] INFO: Got successful response from https://www.morizon.pl/oferta/sprzedaz-mieszkanie-krakow-podgorze-mysliwska-68-64m2-mzn2043447269
# 2024-07-10 15:32:36 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.morizon.pl/oferta/sprzedaz-mieszkanie-krakow-podgorze-mysliwska-68-44m2-mzn2043447284> (referer: https://www.morizon.pl/mieszkania/krakow/?page=2)
# 2024-07-10 15:32:36 [my_morizon_spider] INFO: Got successful response from https://www.morizon.pl/oferta/sprzedaz-mieszkanie-krakow-podgorze-mysliwska-68-44m2-mzn2043447284
# 2024-07-10 15:32:41 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.morizon.pl/oferta/sprzedaz-mieszkanie-krakow-mistrzejowice-piasta-kolodzieja-45m2-mzn2042044083> (referer: https://www.morizon.pl/mieszkania/krakow/?page=2)
# 2024-07-10 15:32:41 [my_morizon_spider] INFO: Got successful response from https://www.morizon.pl/oferta/sprzedaz-mieszkanie-krakow-mistrzejowice-piasta-kolodzieja-45m2-mzn2042044083
# 2024-07-10 15:32:47 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.morizon.pl/oferta/sprzedaz-mieszkanie-krakow-mistrzejowice-piasta-kolodzieja-39m2-mzn2042044084> (referer: https://www.morizon.pl/mieszkania/krakow/?page=2)
# 2024-07-10 15:32:47 [my_morizon_spider] INFO: Got successful response from https://www.morizon.pl/oferta/sprzedaz-mieszkanie-krakow-mistrzejowice-piasta-kolodzieja-39m2-mzn2042044084
# 2024-07-10 15:32:53 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.morizon.pl/oferta/sprzedaz-mieszkanie-krakow-pradnik-bialy-zauchy-6-38m2-mzn2043641203> (referer: https://www.morizon.pl/mieszkania/krakow/?page=2)
# 2024-07-10 15:32:53 [my_morizon_spider] INFO: Got successful response from https://www.morizon.pl/oferta/sprzedaz-mieszkanie-krakow-pradnik-bialy-zauchy-6-38m2-mzn2043641203
# 2024-07-10 15:32:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.morizon.pl/oferta/sprzedaz-mieszkanie-krakow-ciesielskiego-37m2-mzn2043682200> (referer: https://www.morizon.pl/mieszkania/krakow/?page=2)
# 2024-07-10 15:32:58 [my_morizon_spider] INFO: Got successful response from https://www.morizon.pl/oferta/sprzedaz-mieszkanie-krakow-ciesielskiego-37m2-mzn2043682200
# 2024-07-10 15:33:02 [scrapy.extensions.logstats] INFO: Crawled 73 pages (at 11 pages/min), scraped 0 items (at 0 items/min)
# 2024-07-10 15:33:04 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.morizon.pl/oferta/sprzedaz-mieszkanie-krakow-pradnik-bialy-conrada-27-68m2-mzn2042977732> (referer: https://www.morizon.pl/mieszkania/krakow/?page=2)
# 2024-07-10 15:33:04 [my_morizon_spider] INFO: Got successful response from https://www.morizon.pl/oferta/sprzedaz-mieszkanie-krakow-pradnik-bialy-conrada-27-68m2-mzn2042977732
# 2024-07-10 15:33:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.morizon.pl/oferta/sprzedaz-mieszkanie-krakow-stare-miasto-prandoty-10c-94m2-mzn2041533782> (referer: https://www.morizon.pl/mieszkania/krakow/?page=2)
# 2024-07-10 15:33:09 [my_morizon_spider] INFO: Got successful response from https://www.morizon.pl/oferta/sprzedaz-mieszkanie-krakow-stare-miasto-prandoty-10c-94m2-mzn2041533782
# 2024-07-10 15:33:15 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.morizon.pl/oferta/sprzedaz-mieszkanie-krakow-stare-miasto-prandoty-10c-36m2-mzn2043903396> (referer: https://www.morizon.pl/mieszkania/krakow/?page=2)
# 2024-07-10 15:33:15 [my_morizon_spider] INFO: Got successful response from https://www.morizon.pl/oferta/sprzedaz-mieszkanie-krakow-stare-miasto-prandoty-10c-36m2-mzn2043903396
# 2024-07-10 15:33:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.morizon.pl/oferta/sprzedaz-mieszkanie-krakow-pradnik-bialy-zauchy-6-89m2-mzn2043330626> (referer: https://www.morizon.pl/mieszkania/krakow/?page=2)
# 2024-07-10 15:33:19 [my_morizon_spider] INFO: Got successful response from https://www.morizon.pl/oferta/sprzedaz-mieszkanie-krakow-pradnik-bialy-zauchy-6-89m2-mzn2043330626
# 2024-07-10 15:33:19 [scrapy.core.engine] INFO: Closing spider (finished)
# 2024-07-10 15:33:19 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 27795,
#  'downloader/request_count': 78,
#  'downloader/request_method_count/GET': 78,
#  'downloader/response_bytes': 3702464,
#  'downloader/response_count': 78,
#  'downloader/response_status_count/200': 77,
#  'downloader/response_status_count/301': 1,
#  'dupefilter/filtered': 74,
#  'elapsed_time_seconds': 376.581758,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2024, 7, 10, 13, 33, 19, 265866, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 15901004,
#  'httpcompression/response_count': 77,
#  'log_count/DEBUG': 80,
#  'log_count/INFO': 90,
#  'log_count/WARNING': 1,
#  'request_depth_max': 1,
#  'response_received_count': 77,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 77,
#  'scheduler/dequeued/memory': 77,
#  'scheduler/enqueued': 77,
#  'scheduler/enqueued/memory': 77,
#  'start_time': datetime.datetime(2024, 7, 10, 13, 27, 2, 684108, tzinfo=datetime.timezone.utc)}
# 2024-07-10 15:33:19 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
import pandas as pd

df = pd.DataFrame.from_records(results)

# %%
df.columns
# Out:
# Index(['price', 'price_per_metr', 'rooms', 'floor', 'location', 'title',
#        'url'],
#       dtype='object')

# %%
df.sample(15)
# Out:
#        price price_per_metr        rooms           floor  \
# 51                            • 2 pokoje    • piętro 3/5
# 10                            • 2 pokoje      • piętro 6
# 66                            • 3 pokoje    • piętro 6/9
# 61                            • 2 pokoje        • parter
# 12                            • 2 pokoje      • piętro 4
# 11                            • 2 pokoje      • piętro 3
# 7                             • 3 pokoje    • piętro 5/5
# 1                             • 3 pokoje      • piętro 3
# 32  770000.0        15400.0   • 2 pokoje    • piętro 1/3
# 43  780000.0        17230.0   • 2 pokoje   • piętro 3/10
# 67                            • 2 pokoje    • piętro 6/9
# 50  638980.0        15035.0   • 2 pokoje    • piętro 1/4
# 60                            • 4 pokoje    • piętro 5/7
# 55                            • 2 pokoje    • piętro 2/9
# 68                            • 2 pokoje      • piętro 4
#
#                                              location  \
# 51   małopolskie, Kraków, ul. Papierni Prądnickich 48
# 10  Kraków, Stare Miasto (historyczne), Stare Mias...
# 66       Kraków, Mistrzejowice, ul. Piasta Kołodzieja
# 61  Kraków, Stare Miasto (historyczne), Stare Mias...
# 12       Kraków, Prądnik Biały, Banacha, ul. Zauchy 6
# 11       Kraków, Prądnik Biały, Banacha, ul. Zauchy 6
# 7                      Kraków, Podgórze, Myśliwska 68
# 1                Kraków, Podgórze Stare, ul. Rydlówka
# 32                 Kraków, Kraków-Podgórze, Zakrzówek
# 43  Kraków, Kraków-Krowodrza, Prądnik Biały, Ks. J...
# 67       Kraków, Mistrzejowice, ul. Piasta Kołodzieja
# 50             Kraków, Bieżanów, Kraków, Potrzask 97d
# 60             małopolskie, Kraków, ul. Ciesielskiego
# 55       Kraków, Mistrzejowice, ul. Piasta Kołodzieja
# 68       Kraków, Prądnik Biały, Banacha, ul. Zauchy 6
#
#                                                 title  \
# 51                                 Opis nieruchomości
# 10                                 Opis nieruchomości
# 66                                 Opis nieruchomości
# 61                                 Opis nieruchomości
# 12                                 Opis nieruchomości
# 11                                 Opis nieruchomości
# 7                                  Opis nieruchomości
# 1                                  Opis nieruchomości
# 32                          Zamieszkaj obok Zakrzówka
# 43   Funkcjonalne mieszkanie o wyjątkowym charakterze
# 67                                 Opis nieruchomości
# 50  GOTOWE do zamieszkania | 2 Pokoje + Garderoba ...
# 60                                 Opis nieruchomości
# 55                                 Opis nieruchomości
# 68                                 Opis nieruchomości
#
#                                                   url
# 51  https://www.morizon.pl/oferta/sprzedaz-mieszka...
# 10  https://www.morizon.pl/oferta/sprzedaz-mieszka...
# 66  https://www.morizon.pl/oferta/sprzedaz-mieszka...
# 61  https://www.morizon.pl/oferta/sprzedaz-mieszka...
# 12  https://www.morizon.pl/oferta/sprzedaz-mieszka...
# 11  https://www.morizon.pl/oferta/sprzedaz-mieszka...
# 7   https://www.morizon.pl/oferta/sprzedaz-mieszka...
# 1   https://www.morizon.pl/oferta/sprzedaz-mieszka...
# 32  https://www.morizon.pl/oferta/sprzedaz-mieszka...
# 43  https://www.morizon.pl/oferta/sprzedaz-mieszka...
# 67  https://www.morizon.pl/oferta/sprzedaz-mieszka...
# 50  https://www.morizon.pl/oferta/sprzedaz-mieszka...
# 60  https://www.morizon.pl/oferta/sprzedaz-mieszka...
# 55  https://www.morizon.pl/oferta/sprzedaz-mieszka...
# 68  https://www.morizon.pl/oferta/sprzedaz-mieszka...

# %%
pd.DataFrame(df.iloc[13])
# Out:
#                                                                13
# price
# price_per_metr
# rooms                                                  • 3 pokoje
# floor                                                  • piętro 2
# location            Kraków, Podgórze Duchackie, ul. Białoruska 69
# title                                          Opis nieruchomości
# url             https://www.morizon.pl/oferta/sprzedaz-mieszka...

# %%
from datetime import datetime

now = datetime.now().strftime("%Y-%m-%d")
fname = f"data/morizon-{now}.csv"
fname
# Out:
# 'data/morizon-2024-07-10.csv'

# %%
df.to_csv(fname)
